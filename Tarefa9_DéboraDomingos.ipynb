# %% [markdown]
# Débora Domingos - 11202212420

# %%
#Importando o pandas
import pandas as pd

#importando o matplotlib
import matplotlib.pyplot as plt

# %%
#Importando a base de analfabetismo
base = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/analfabetismo.csv')

# %%
#visualizando as 3 primeiras linhas
base.head(3)
# Out:
#     Ano       Acre    Alagoas   Amazonas      Amapá      Bahia      Ceará  \
# 0  1981  24.771344  48.714720  13.740147  16.864253  36.535406  42.453047
# 1  1982  20.682421  53.185056  16.232134  12.843550  36.971875  44.385931
# 2  1983  20.823673  51.491081  10.814711  13.890302  35.278137  42.979866
#
#    Distrito Federal  Espírito Santo      Goiás  ...     Paraná  \
# 0         11.212273       22.497828  24.408604  ...  20.287721
# 1          9.902721       25.009842  24.515374  ...  20.868585
# 2         10.611223       21.918142  22.788413  ...  19.946446
#
#    Rio de Janeiro  Rio Grande do Norte   Rondônia    Roraima  \
# 0       11.707655            41.634136  20.128014   9.138271
# 1       11.605974            39.494989  19.557072  13.383961
# 2       10.601789            42.384636  14.922802   5.685683
#
#    Rio Grande do Sul  Santa Catarina    Sergipe  São Paulo  Tocantins
# 0          12.830248       12.911638  39.670939  12.523352        NaN
# ...

# %%
#visualizando as 3 ultimas linhas
base.tail(3)
# Out:
#      Ano       Acre    Alagoas  Amazonas     Amapá      Bahia      Ceará  \
# 27  2012  13.461716  21.834940  8.269417  6.723025  15.893686  16.274337
# 28  2013  14.606067  21.647721  7.337762  5.966746  14.913226  16.722980
# 29  2014  13.079072  21.971093  6.204441  4.215737  14.740348  16.284987
#
#     Distrito Federal  Espírito Santo     Goiás  ...    Paraná  Rio de Janeiro  \
# 27          3.485900        6.734058  7.292910  ...  5.267335        3.789665
# 28          3.186502        6.592571  7.055984  ...  5.330169        3.736142
# 29          2.728544        6.549233  7.682399  ...  4.954787        3.206950
#
#     Rio Grande do Norte  Rondônia   Roraima  Rio Grande do Sul  \
# 27            16.041607  8.572059  7.391402           4.256847
# 28            17.166137  8.558027  9.806430           4.425117
# 29            16.209008  8.335295  7.468176           4.466359
#
#     Santa Catarina    Sergipe  São Paulo  Tocantins
# ...

# %%
#visualizando os tipos de dados
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ano                  30 non-null     int64
#  1   Acre                 30 non-null     float64
#  2   Alagoas              30 non-null     float64
#  3   Amazonas             30 non-null     float64
#  4   Amapá                30 non-null     float64
#  5   Bahia                30 non-null     float64
#  6   Ceará                30 non-null     float64
#  7   Distrito Federal     30 non-null     float64
#  8   Espírito Santo       30 non-null     float64
#  9   Goiás                30 non-null     float64
#  10  Maranhão             30 non-null     float64
#  11  Minas Gerais         30 non-null     float64
#  12  Mato Grosso do Sul   30 non-null     float64
#  13  Mato Grosso          30 non-null     float64
#  14  Pará                 30 non-null     float64
# ...

# %%
#mantendo apenas a coluna de anos e de são paulo.

base = base[['Ano', 'São Paulo']]
base.head(3)
# Out:
#     Ano  São Paulo
# 0  1981  12.523352
# 1  1982  12.740826
# 2  1983  11.785755

# %%
#Plotando o Grafico
plt.figure(figsize=(20, 8))
plt.plot('Ano','São Paulo',data=base);
