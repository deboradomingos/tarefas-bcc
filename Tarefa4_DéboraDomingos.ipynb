# %% [markdown]
# Débora Domingos - 11202212420

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# Fórmula - V = 4 * π * R**3 / 3
#
# Teste para:
#
# a) R = 0,32m;

# %%
π = 3.14
R = 0.32
volumetotal = (4 * π * R**3) / 3
print("O volume da esfera é de " + str(volumetotal) + " m^3")
# Out:
# O volume da esfera é de 0.13718869333333336 m^3

# %% [markdown]
# b) R = 1m;

# %%
π = 3.14
R = 1
volume = (4 * π * R**3) / 3
print("O volume da esfera é de " + str(volume) + " m^3")
# Out:
# O volume da esfera é de 4.1866666666666665 m^3

# %% [markdown]
# c) R = 1,9m;

# %%
π = 3.14
R = 1.9
vol = (4 * π * R**3) / 3
print("O volume da esfera é de " + str(vol) + " m^3")
# Out:
# O volume da esfera é de 28.716346666666663 m^3

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Fórmula - 32 + (9/5) * C
#
# Teste para:
#
# a) Tc = -10ºC;

# %%
C = -10
F = 32 +  (9/5) * C
print("-10ºC é igual a " + str(F) + "ºF")
# Out:
# -10ºC é igual a 14.0ºF

# %% [markdown]
# b) Tc = 30ºC;

# %%
C = 30
Fr = 32 +  (9/5) * C
print("30ºC é igual a " + str(Fr) + "ºF")
# Out:
# 30ºC é igual a 86.0ºF

# %% [markdown]
# c) Tc = 5 ºC

# %%
C = 
Fahrenheit = 32 +  (9/5) * C
print("5ºC é igual a " + str(Fahrenheit) + "ºF")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#   ![image.png](data:image/png;base64,...)
#
#   Fórmula - c = a^2 + b^2 - 2 * a * b * cosΘ, sendo a raiz = c^1/2.
#
#   Teste para:
#
#   a) a = 1, b = 2 e Θ = 30º

# %%
import math
cosΘ = 3/2
raiz = math.sqrt(cosΘ)
print(raiz)
# Out:
# 1.224744871391589

# %%
a = 1
b = 2
cosΘ = 1.224744871391589
c = a**2 + b**2 - 2 * a * b * cosΘ
raiz = c**1/2
print(raiz)
# Out:
# 0.05051025721682212

# %% [markdown]
# b) a = 3, b = 1 e Θ = 45º

# %%
import math
cosΘ = 2/2
raiz = math.sqrt(cosΘ)
print(raiz)
# Out:
# 1.0

# %%
a = 3
b = 1
cosΘ = 1.0
c = a**2 + b**2 - 2 * a * b * cosΘ
raiz = c**1/2
print(raiz)
# Out:
# 2.0

# %% [markdown]
# c) a = 10, b = 11 e Θ = 15º

# %%
import math
cosΘ = 6+2/4
raiz = math.sqrt(cosΘ)
print(raiz)
# Out:
# 2.5495097567963922

# %%
a = 10
b = 11
cosΘ = 2.5495097567963922
c = a**2 + b**2 - 2 * a * b * cosΘ
raiz = c**1/2
print(raiz)
# Out:
# -169.89

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Fórmula - Fi = [(1+{5^1/2}/2)^i - (1-{5^1/2}/2)^i / 5^1/2]
#
# Teste para:
#
# a) i = 30

# %%
i = 30
Fi = ((((1+5**0.5)/2)**i) - (((1-5**0.5)/2)**i))/5**0.5
Fi=int(Fi)
print(Fi)
# Out:
# 832040

# %% [markdown]
# b) i = 31

# %%
i = 31
Fi = ((((1+5**0.5)/2)**i) - (((1-5**0.5)/2)**i))/5**0.5
Fi=int(Fi)
print(Fi)
# Out:
# 1346269

# %% [markdown]
# c) i = 32

# %%
i = 32
Fi = ((((1+5**0.5)/2)**i) - (((1-5**0.5)/2)**i))/5**0.5
Fi=int(Fi)
print(Fi)
# Out:
# 2178309
